# %%
import DeeperTradeLibrary

# %%
import pandas as pd

# %%
df = pd.read_csv('SPX500_USD_D_260919.csv')

# %%
df.set_index('time', inplace=True)

# %%
df.head()
# Out:
#                             open   high    low  close  volume
# time
# 2003-03-23 22:00:00+00:00  882.7  883.2  861.9  864.4     823
# 2003-03-24 22:00:00+00:00  863.4  880.4  857.6  874.2     815
# 2003-03-25 22:00:00+00:00  874.4  876.7  866.6  869.6     791
# 2003-03-26 22:00:00+00:00  867.6  874.9  858.1  868.9     770
# 2003-03-27 22:00:00+00:00  870.1  870.4  860.8  863.9     787

# %%
DeeperTradeLibrary.Indicators.addAllTechnicalIndicators(df)
# Out:
# /home/charles/.local/lib/python3.6/site-packages/ta/trend.py:543: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# /home/charles/.local/lib/python3.6/site-packages/ta/trend.py:547: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])
#                              open    high     low   close  volume  \
# time
# 2003-03-23 22:00:00+00:00   882.7   883.2   861.9   864.4     823
# 2003-03-24 22:00:00+00:00   863.4   880.4   857.6   874.2     815
# 2003-03-25 22:00:00+00:00   874.4   876.7   866.6   869.6     791
# 2003-03-26 22:00:00+00:00   867.6   874.9   858.1   868.9     770
# 2003-03-27 22:00:00+00:00   870.1   870.4   860.8   863.9     787
# ...                           ...     ...     ...     ...     ...
# 2019-09-19 21:00:00+00:00  3004.6  3015.2  2982.8  2986.8   10461
# 2019-09-22 21:00:00+00:00  2999.6  3005.6  2979.6  2998.8    8852
# ...
